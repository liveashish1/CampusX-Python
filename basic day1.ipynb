# %% [markdown]
# **print all**

# %%
#class 1  print function


print('ashish') # case sens
# Out:
# ashish

# %%
Print() #error
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-cdb803c18837> in <module>
# ----> 1 Print() #error
#
# NameError: name 'Print' is not defined

# %%
print(5)

# %%
a='as'
type(a)

# %%
print('ashish',1,3,True)

# %%
print('ashish',1,3,True,sep='  ')

# %%
print('ashish',1,3,True,sep='/')

# %%
print(ashish)
print (pal)

# %%
print('ashish')
print ('pal')

# %%
print('ashihs',end='-')
print('pal')

# %% [markdown]
# data types

# %%
##data types
#integer
print(8)
##limitation not requried##

# %%
#decimal/float

print(9.0)

# %%
#bolean ##1##0 bollean not text
print(True)

# %%
#text/string
print('hello da')

# %%
#complex
print(3+6j)

# %%
#list in c=array

print([1,2,3,4])

# %%
#tuple
print((1,2,3,4))

# %%
#sets
print({1,2,3,4})

# %%
#dictionary

print({"name":"ashish","surname":"pal"})
# Out:
# {'name': 'ashish', 'surname': 'pal'}

# %%
#dictionary

print({'name':'ashish',"surname":"pal"})
# Out:
# {'name': 'ashish', 'surname': 'pal'}

# %%
#type fun
type(3)
type('ashihs')
type([1,2])
# Out:
# list

# %%
##variable

# %%
a="ashihs"

# %%
print(a)
# Out:
# ashihs

# %%
type(a)
# Out:
# str

# %%
#dynamic typing python
#in c we need to define int static

# %%
##dynamic binding
##static binding

# %%
a,b,c=1,1,1
print(a,b,c)
# Out:
# 1 1 1

# %%
a=b=c=5

# %%
print(a,b,c,end="--")
print('apal')
# Out:
# 5 5 5--apal

# %%
print()

# %%
##comments

##

# %%
##keywords

# %%
#compilation is we convert code into binanry number

# %%
#intepreter one by one in python

# %% [markdown]
# #new

# %%
# Identifiers
# You can't start with a digit
name1 = 'ashish'
print(name1)
# You can use special chars -> _
_ = 'ashish'
print(_)
# identiers can not be keyword
# Out:
# ashish
# ashish

# %% [markdown]
# # input

# %%
input('naam bata "lav##da"')
# Out:
# naam bata "lav##da"45
# '45'

# %%
a=input('enter no')
b=input('enter no')
print(type(a),type(b))
print(a+b)
# Out:
# enter no5
# enter no5
# <class 'str'> <class 'str'>
# 55

# %%
#string is universal format

# %%
#type conversion to convert data type
#implict vs Explict

# %%
# Implicit Vs Explicit
print(5+5.6)
print(type(5),type(5.6))

#unsupported operand type(s) for +: 'int' and 'str'

print(4 + '4')
# Out:
# 10.6
# <class 'int'> <class 'float'>
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-38-dab428d18744> in <module>
#       5 #unsupported operand type(s) for +: 'int' and 'str'
#       6
# ----> 7 print(4 + '4')
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %%
a='4'
type(a)
# Out:
# str

# %%
int('a')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-42-233884bacd4e> in <module>
# ----> 1 int('a')
#
# ValueError: invalid literal for int() with base 10: 'a'

# %%
a=input('enter no')
b=input('enter no')
res=int(a)+int(b) 
print(res)
# Out:
# enter no4
# enter no4
# 8

# %%
res=int(a)+int(b) 
print(res)
# Out:
# 8

# %%
print()

# %% [markdown]
# #literals copy

# %%
a = 0b1010 #Binary Literals--0b
b = 100 #Decimal Literal 
c = 0o310 #Octal Literal--0o
d = 0x12c #Hexadecimal Literal--0x
print(a,b,c,d)


#Float Literal
float_1 = 10.5 
float_2 = 1.5e2 # 1.5 * 10^2--+vw
float_3 = 1.5e-3 # 1.5 * 10^-3-- -vw

#Complex Literal 
x = 3.14j

print(a, b, c, d,x)
print(float_1, float_2,float_3)
print(x, x.imag, x.real)
# Out:
# 10 100 200 300
# 10 100 200 300 3.14j
# 10.5 150.0 0.0015
# 3.14j 3.14 0.0

# %%
string = 'This is Python'
strings = "This is Python"
char = "C"
multiline_str = """This is a multiline string with more than one line code."""
unicode = u"\U0001f600\U0001F606\U0001F923"
raw_str = r"raw \n string"

print(string)
print(strings)
print(char)
print(multiline_str)
print(unicode)
print(raw_str)
# Out:
# This is Python
# This is Python
# C
# This is a multiline string with more than one line code.
# 😀😆🤣
# raw \n string

# %%
a = True + 4
b = False + 10

print("a:", a)
print("b:", b)
# Out:
# a: 5
# b: 10

# %%
k 
a = 5
b = 6
print('Program exe')
# Out:
# Program exe

# %%
k = None
a = 5
b = 6
print('Program exe')
# Out:
# Program exe
